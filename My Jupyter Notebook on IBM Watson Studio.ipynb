# %% [markdown]
#  # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Saeed Hashemi Halvaei__
#
# Data Scientist

# %% [markdown]
# _The reason I wanted to start this journey is the how data science gives me an ability to recognize patterns behind data

# %% [markdown]
# ### this codw will sum to variable that will be give to it

# %%
def sum(n1,n2):
    r=n1+n2
    return r

print(sum(5))

# %% [markdown]
# - sum
# - devide
#
# 1. n1
# 2. n2
#
#
# ![photo.jpg](attachment:photo.jpg)
